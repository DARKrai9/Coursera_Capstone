# %%
from urllib import request
import pandas as pd
import wikipedia

# %% [markdown]
# <h3>Fecth and convert table in Data frame (df)</h3>

# %%
html_page=wikipedia.page("List_of_postal_codes_of_Canada:_M").html().encode("UTF-8")

# %%
df=pd.read_html(html_page,header=0)[0]

# %%
df
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                           Neighborhood
# 0                                                  NaN
# 1                                                  NaN
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                           Regent Park / Harbourfront
# ..                                                 ...
# 175                                                NaN
# 176                                                NaN
# ...

# %% [markdown]
# <h3>Remove "Not assigned" Borough</h3>

# %%
df=df.set_index("Borough")
df=df.drop('Not assigned',axis=0)
df=df.reset_index()

# %%
df
# Out:
#               Borough Postal Code  \
# 0          North York         M3A
# 1          North York         M4A
# 2    Downtown Toronto         M5A
# 3          North York         M6A
# 4    Downtown Toronto         M7A
# ..                ...         ...
# 98          Etobicoke         M8X
# 99   Downtown Toronto         M4Y
# 100      East Toronto         M7Y
# 101         Etobicoke         M8Y
# 102         Etobicoke         M8Z
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                           Regent Park / Harbourfront
# 3                    Lawrence Manor / Lawrence Heights
# 4         Queen's Park / Ontario Provincial Government
# ..                                                 ...
# 98     The Kingsway / Montgomery Road / Old Mill North
# 99                                Church and Wellesley
# ...

# %% [markdown]
# <h3>Same postalcode Neighborhood in one row</h3>

# %%
for i in range(0,len(df)):
    df.iloc[i,2]=df.iloc[i,2].replace("/",',')
df
# Out:
#               Borough Postal Code  \
# 0          North York         M3A
# 1          North York         M4A
# 2    Downtown Toronto         M5A
# 3          North York         M6A
# 4    Downtown Toronto         M7A
# ..                ...         ...
# 98          Etobicoke         M8X
# 99   Downtown Toronto         M4Y
# 100      East Toronto         M7Y
# 101         Etobicoke         M8Y
# 102         Etobicoke         M8Z
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                           Regent Park , Harbourfront
# 3                    Lawrence Manor , Lawrence Heights
# 4         Queen's Park , Ontario Provincial Government
# ..                                                 ...
# 98     The Kingsway , Montgomery Road , Old Mill North
# 99                                Church and Wellesley
# ...

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# <h3>Add Latitude and Longitude columns</h3>

# %%
Geospatial_data="Geospatial_Coordinates.csv"
Geo_df=pd.read_csv(Geospatial_data)

# %%
Geo_df
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
df['Latitude']=""
df['Longitude']=""

# %%
for i in range(0,len(df)):
    ind=Geo_df.index[Geo_df["Postal Code"]==df.loc[i,"Postal Code"]].tolist()
    df.loc[i,'Latitude']=Geo_df.loc[ind[0],"Latitude"]
    df.loc[i,"Longitude"]=Geo_df.loc[ind[0],"Longitude"]
df
# Out:
#               Borough Postal Code  \
# 0          North York         M3A
# 1          North York         M4A
# 2    Downtown Toronto         M5A
# 3          North York         M6A
# 4    Downtown Toronto         M7A
# ..                ...         ...
# 98          Etobicoke         M8X
# 99   Downtown Toronto         M4Y
# 100      East Toronto         M7Y
# 101         Etobicoke         M8Y
# 102         Etobicoke         M8Z
#
#                                           Neighborhood Latitude Longitude
# 0                                            Parkwoods  43.7533  -79.3297
# 1                                     Victoria Village  43.7259  -79.3156
# 2                           Regent Park , Harbourfront  43.6543  -79.3606
# 3                    Lawrence Manor , Lawrence Heights  43.7185  -79.4648
# 4         Queen's Park , Ontario Provincial Government  43.6623  -79.3895
# ..                                                 ...      ...       ...
# ...
